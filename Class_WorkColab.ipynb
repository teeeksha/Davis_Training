# %% [markdown]
# <a href="https://colab.research.google.com/github/teeeksha/Davis_Training/blob/main/Class_WorkColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

# input
n = int(input("Enter a number: "))

# function call
result = check_even_odd(n)

# output
print(result)
# Out:
# Enter a number: 90
# Even
